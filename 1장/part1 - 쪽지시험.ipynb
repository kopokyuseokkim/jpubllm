# %% [markdown]
# **질문 1.** 자연계에서 동물, 식물의 형태적이나 구조적 특징으로부터 아이디어를 얻어 실생활에 활용할 수 있는 기술을 __ __ __이라 합니다.

# %% [markdown]
# 정답. 생체 모방 기술

# %% [markdown]
# **질문 2.** 자연 지능의 __과 __을 통해 인류는 진화하였습니다.

# %% [markdown]
# 정답. 학습, 예측

# %% [markdown]
# **질문 3**. 신경계에서 가장 기본의 단위는 __입니다.

# %% [markdown]
# 정답. 뉴런

# %% [markdown]
# **질문 4.** 딥러닝의 시초가 된 ___-__ 모델은 퍼셉트론-뉴럴 네트워크(Neural network) - 딥러닝(Deep learning)으로 발전하였습니다.

# %% [markdown]
# 정답. 맥컬로-피츠

# %% [markdown]
# **질문 5.** 인공지능의 기준은 3단계를 가지고 있으며 약인공지능, _____, 초인공지능의 순서를 가집니다.

# %% [markdown]
# 정답. 강인공지능
